# %%
# Pip install packages
import os, sys

# !pip install azure-storage-blob
# !pip install pyarrow
# !pip install pandas
# Out:
# Requirement already satisfied: azure-storage-blob in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (12.25.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (4.14.1)
# Requirement already satisfied: azure-core>=1.30.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (45.0.5)
# Requirement already satisfied: six>=1.11.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.4)
# Requirement already satisfied: cffi>=1.14 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.7.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyarrow in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (20.0.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: six>=1.5 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Azure storage access info
azure_storage_account_name = "azureopendatastorage"
azure_storage_sas_token = r""
container_name = "laborstatisticscontainer"
folder_name = "ehe_national/"

# %%
# %pip install azure-storage-blob

from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

if azure_storage_account_name is None or azure_storage_sas_token is None:
    raise Exception(
        "Provide your specific name and key for your Azure Storage account--see the Prerequisites section earlier.")

print('Looking for the first parquet under the folder ' +
      folder_name + ' in container "' + container_name + '"...')
container_url = f"https://{azure_storage_account_name}.blob.core.windows.net/"
blob_service_client = BlobServiceClient(
    container_url, credential=azure_storage_sas_token if azure_storage_sas_token else None)

container_client = blob_service_client.get_container_client(container_name)
blobs = container_client.list_blobs(name_starts_with=folder_name)
sorted_blobs = sorted(list(blobs), key=lambda e: e.name, reverse=True)
targetBlobName = ''
for blob in sorted_blobs:
    if blob.name.startswith(folder_name) and blob.name.endswith('.parquet'):
        targetBlobName = blob.name
        break

if not targetBlobName:
    raise Exception("No parquet file found in the specified folder.")

print('Target blob to download: ' + targetBlobName)
_, filename = os.path.split(targetBlobName)
blob_client = container_client.get_blob_client(targetBlobName)
with open(filename, 'wb') as local_file:
    blob_client.download_blob().download_to_stream(local_file)
# Out:
# Requirement already satisfied: azure-storage-blob in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (12.25.1)
# Requirement already satisfied: azure-core>=1.30.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (45.0.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (4.14.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: idna<4,>=2.5 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.7.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\new folder (5)\mcpserverlangchain\mcpdatavisbackend\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking for the first parquet under the folder ehe_national/ in container "laborstatisticscontainer"...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Target blob to download: ehe_national/part-00000-tid-2154474300105623564-5707b7d6-a6d4-45a1-b940-3b20a4819ccc-41564-c000.snappy.parquet

# %%
# Read the parquet file into Pandas data frame
import pandas as pd

print('Reading the parquet file into Pandas data frame')
df = pd.read_parquet(filename)
# Out:
# Reading the parquet file into Pandas data frame

# %%
# you can add your filter at below
print('Loaded as a Pandas data frame: ')
df
# Out:
# Loaded as a Pandas data frame:
#         data_type_code industry_code supersector_code      series_id  year  \
# 0                   26       5000000                5  CES0500000026  1939
# 1                   26       5000000                5  CES0500000026  1939
# 2                   26       5000000                5  CES0500000026  1939
# 3                   26       5000000                5  CES0500000026  1939
# 4                   26       5000000                5  CES0500000026  1939
# ...                ...           ...              ...            ...   ...
# 7642405             24      30000000               30  CEU3000000024  2019
# 7642406             24      30000000               30  CEU3000000024  2019
# 7642407             24      30000000               30  CEU3000000024  2019
# 7642408             24      30000000               30  CEU3000000024  2019
# 7642409             24      30000000               30  CEU3000000024  2019
#
#         period       value footnote_codes seasonal  \
# 0          M04   52.000000            nan        S
# 1          M05   65.000000            nan        S
# 2          M06   74.000000            nan        S
# 3          M07  103.000000            nan        S
# 4          M08  108.000000            nan        S
# ...        ...         ...            ...      ...
# 7642405    M03   74.300003            nan        U
# 7642406    M04   75.699997            nan        U
# 7642407    M05   70.400002            nan        U
# 7642408    M06   70.400002              P        U
# 7642409    M07   71.099998              P        U
#
#                                               series_title supersector_name  \
# 0        All employees, 3-month average change, seasona...    Total private
# 1        All employees, 3-month average change, seasona...    Total private
# 2        All employees, 3-month average change, seasona...    Total private
# 3        All employees, 3-month average change, seasona...    Total private
# 4        All employees, 3-month average change, seasona...    Total private
# ...                                                    ...              ...
# 7642405  Diffusion indexes, 12-month span, not seasonal...    Manufacturing
# 7642406  Diffusion indexes, 12-month span, not seasonal...    Manufacturing
# 7642407  Diffusion indexes, 12-month span, not seasonal...    Manufacturing
# 7642408  Diffusion indexes, 12-month span, not seasonal...    Manufacturing
# 7642409  Diffusion indexes, 12-month span, not seasonal...    Manufacturing
#
#          industry_name                                     data_type_text
# 0        Total private  ALL EMPLOYEES, 3-MONTH AVERAGE CHANGE, SEASONA...
# 1        Total private  ALL EMPLOYEES, 3-MONTH AVERAGE CHANGE, SEASONA...
# 2        Total private  ALL EMPLOYEES, 3-MONTH AVERAGE CHANGE, SEASONA...
# 3        Total private  ALL EMPLOYEES, 3-MONTH AVERAGE CHANGE, SEASONA...
# 4        Total private  ALL EMPLOYEES, 3-MONTH AVERAGE CHANGE, SEASONA...
# ...                ...                                                ...
# 7642405  Manufacturing  DIFFUSION INDEXES, 12-MONTH SPAN, NOT SEASONAL...
# 7642406  Manufacturing  DIFFUSION INDEXES, 12-MONTH SPAN, NOT SEASONAL...
# 7642407  Manufacturing  DIFFUSION INDEXES, 12-MONTH SPAN, NOT SEASONAL...
# 7642408  Manufacturing  DIFFUSION INDEXES, 12-MONTH SPAN, NOT SEASONAL...
# 7642409  Manufacturing  DIFFUSION INDEXES, 12-MONTH SPAN, NOT SEASONAL...
#
# [7642410 rows x 13 columns]
